# %% [markdown]
# #1 - Criando um título poderoso

# %% [markdown]
# ### Prompt usado:

# %%
'''Você é um roteirista de podcast, e vamos criar um podcast de tecnologia, focado
em front end e eu gostaria de uma ajuda sua para criar 5 sugestões de nomes criativos
para um podcast de front end feito por nerds, e que tenha algum trocadilho nerd no nome

O podcast vai falar sobre dicas e novidades sobre o mundo do front end e o que está
acontecendo no mercado

{REGRAS}

- O nome deve ser enxuto, um nome e um subtítulo
- O nome tenha algum trocadilho nerd com nomes de franquias conhecidas como harry potter,
star wars ou senhor dos anéis
- O nome deve conter alguma palavra forte que remeta a front end

{REGRAS NEGATIVAS}

- Não quero que o título contenha palavras em inglês
- Não quero que utilize nenhuma das palavras nessa lista: Javascript, programador
- Não utilize a palavra frontend no nome nem qualquer variação dela''

# %% [markdown]
# [resultado](https://https://chatgpt.com/s/t_68d77480bcd881919c8f91c35184c1eb)

# %% [markdown]
# 1. “A Sociedade do CSS — A Irmandade do Código Bonito”
# (Paródia de A Sociedade do Anel, reforçando a ideia de união e estética no front)
#
# 2. “Os Últimos Seletores — Uma Nova Esperança na Interface”
# (Inspirado em Star Wars, fazendo referência direta a seletores de estilo e interfaces)
#
# 3. “A Ordem do Layout — O Cálice Responsivo”
# (Alusão a Harry Potter e o Cálice de Fogo, com foco em responsividade e design)
#
# 4. “O Retorno do Pixel — A Vingança do Design”
# (Baseado em O Retorno do Jedi, brincando com pixel art, design e interface)
#
# 5. “As Duas Divs — O Confronto das Interfaces”
# (Inspirado em As Duas Torres, mas trazendo a clássica div para o centro da piada)

# %% [markdown]
# #2 - Imagens de Capa e MidJourney

# %% [markdown]
# ###Prompt usado:

# %%
'''a podcaster young guy bald hair smiling with microphone, side by side night city,
camera settings f/ 8, 1/ 100s, ISO 100, complex lighting, backlighting, dynamic cinematic
lighting, global illumination, ultra-high resolution,realistic filter of real colors,
photo processing in 16K, cinematic, photorealistic, hyperrealistic ,hyper realistic,
cinematic light, ultra realistic photography, ultra detailed --ar 1:1 --v 5.2''

# %% [markdown]
# [Capas - Podcaster young Guys's](https://drive.google.com/drive/folders/1sakVUHnN7SrD9meQOcgK9rLEiKew5rRB?usp=sharing)

# %%
'''create knight character as podcaster medieval with microphone, retro style,
isometric, cube, game style, low resolution, down angle , game boy colors, 8 bits,
retro sprites --ar 1:1 --v 5.2''

# %% [markdown]
# [Capas - Podcaster mediaval with micropfone](https://drive.google.com/drive/folders/1yfOew5Px2Px8BCj4chbU-9u7VFcfiYyc?usp=sharing)

# %% [markdown]
# #3 - Criando um roteiro de variáveis

# %% [markdown]
# ###Prompt usado:

# %%
'''Você é um roteirista de podcast, e vamos criar um  roteiro de um podcast de tecnologia,
focado em frontend cujo o nome é "DevQuest - A Ordem dos Desenvolvedores" e tem foco em
frontend,  com o público alvo de iniciantes em frontend

o formato do roteiro deve ser
[INTRODUÇÃO]
[CURIOSIDADE 1]
[CURIOSIDADE 2]
[FINALIZAÇÃO]

{REGRAS}

- no bloco [INTRODUÇÃO] substitua por uma introdução iguais as introduções dos vídeos
do canal 'ei nerd', como se fossem escritos pelo Peter Jordan
- no bloco [CURIOSIDADE 1] substitua por uma curiosidade de CSS
- no bloco [CURIOSIDADE 2] sobre uma ferramenta para front ends
- no bloco [FINALIZAÇÃO] substitua por uma despedida cool com o final 'Eu sou o
Josemar e esse foi o CodeQuest dessa semana'
- use termos de fácil explicação
- O podcast vai ser apresentado somente por uma pessoa, chamada Felipão
- O podcast deve ser curto

{REGRAS NEGATIVAS}

- Não use muitos termos técnicos
- Não ultrapasse 5 minutos de duração''

# %% [markdown]
# [resultado](https://chatgpt.com/s/t_68d783592e7081919302f1e73964d5d1)
#
# DevQuest – A Ordem dos Desenvolvedores
#
# [INTRODUÇÃO]
# “Salve, galera nerd do código! Vocês já sabem: aqui é o Josemar e hoje a gente vai mergulhar naquele universo mágico onde as linhas viram telas, os cliques viram aventuras e cada detalhe importa. Se o Frodo tinha o Um Anel, a gente tem o Um Pixel — e a nossa missão é deixar ele perfeito! Então segura aí, porque começa agora mais uma jornada no DevQuest – A Ordem dos Desenvolvedores!”
#
# [CURIOSIDADE 1 – CSS]
# “Você sabia que dá pra mudar a cor de qualquer seleção de texto no site usando só CSS? É só usar o ::selection. Tipo, quando você arrasta o mouse e marca uma frase, em vez daquele azulzão padrão, pode aparecer vermelho, verde ou até um degradê estiloso. Pequenos detalhes assim fazem a interface parecer muito mais caprichada e dão uma experiência diferente pro usuário. Coisa simples, mas que já deixa o site com uma cara única.”
#
# [CURIOSIDADE 2 – Ferramenta]
# “E falando em deixar a vida mais fácil, se você tá começando agora, uma ferramenta que pode salvar seu tempo é o Figma. Ele não é só pra designer não, viu? Com o Figma você consegue ver como o site vai ficar antes de escrever uma linha de código. Dá pra inspecionar espaçamento, cores, fontes e até copiar valores direto pro seu CSS. É como ter um mapa da Terra-média antes de começar a jornada — você sabe exatamente por onde andar e não se perde no meio do caminho.”
#
# [FINALIZAÇÃO]
# “E é isso, meus queridos dev-aventureiros! Espero que essas dicas deixem sua jornada no front mais leve e divertida. Lembra: cada detalhe conta, e cada código escrito é um passo a mais nessa aventura. Eu sou Josemar e esse foi o CodeQuest dessa semana.”

# %% [markdown]
# #4 - Gerando o áudio com Eleven Labs

# %% [markdown]
# [Áudio com o Eleven Labs e Capcut ](https://soundcloud.com/josemar-jomar/podcast-ai-studio?si=6b251084709942349c7ff8dc88bf3346&utm_source=clipboard&utm_medium=text&utm_campaign=social_sharing)

# %% [markdown]
# ***Devido o máximo de caracteres suportados ser de 1000, o roteiro foi reduzido/adaptado:***
#
#
#
#
# `"Olá, galera nerd do código! Vocês sabem: aqui é o Josemar e a gente vai mergulhar no universo mágico onde as linhas viram telas, cliques viram aventuras e cada detalhe importa. Se o Frodo tinha o Um Anel, a gente tem o Um Pixel e a missão é deixar ele perfeito! Então segura aí, porque começa mais uma jornada no DevQuest – A Ordem dos Dev's."`
#
#
#
#
#
# `"Você sabia que dá pra mudar a côr de qualquer seleção de texto no site usando só CSS? É só usar o selection. Tipo, quando você arrasta o mouse e marca uma frase, em vez daquele azulzão padrão, pode aparecer vermelho, verde e até um degradê estiloso. Detalhes assim fazem a interface parecer muito mais caprichada e dão uma experiência diferente pro usuário. Coisa simples, mas que deixa o site com uma cara única."`
#
#
#
# `"E é isso, meus queridos dev-aventureiros! Espero que essas dicas deixem sua jornada no front mais leve e divertida. Lembra: cada detalhe conta, e cada código escrito é um passo a mais nessa aventura. Sou o Josemar e esse foi o CodeQuest d'hoje."`
